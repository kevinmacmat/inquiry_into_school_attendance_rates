# %% [markdown]
# # Import modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import pickle
import re
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %% [markdown]
# ---

# %% [markdown]
# # Schools Data

# %% [markdown]
# https://infohub.nyced.org/reports/school-quality/school-quality-reports-and-resources

# %% [markdown]
# ### Read in data

# %%
df = pd.read_excel('201819_ems_sqr_results.xlsx', index_col=1)

# %% [markdown]
# ### Remove rows to set headers

# %%
headers = df.iloc[0]
df  = pd.DataFrame(df.values[1:], columns=headers)

# %%
headers = df.iloc[0]
df  = pd.DataFrame(df.values[1:], columns=headers)

# %%
headers = df.iloc[0]
df  = pd.DataFrame(df.values[1:], columns=headers)

# %%
df = df.drop(df.index[0])

# %% [markdown]
# ### Reset index and drop old index

# %%
df = df.reset_index()

# %% [markdown]
# ### Drop NaN columns

# %%
df = df.dropna(axis=1, how='all')

# %% [markdown]
# ### Drop old index column

# %%
df = df.drop(columns='index')

# %% [markdown]
# ### Function to check NaN values

# %%
def nan_values(col_name):
    for col in col_name:
        print('column name: ' + col)
        print(df[col].isna().value_counts())

# %%
nan_values(list(df.columns))
# Out:
# column name: DBN
# False    1293
# Name: DBN, dtype: int64
# column name: School Name
# False    1293
# Name: School Name, dtype: int64
# column name: School Type
# False    1293
# Name: School Type, dtype: int64
# column name: Enrollment
# False    1293
# Name: Enrollment, dtype: int64
# column name: Rigorous Instruction Rating
# False    1243
# True       50
# Name: Rigorous Instruction Rating, dtype: int64
# column name: Collaborative Teachers Rating
# False    1243
# True       50
# Name: Collaborative Teachers Rating, dtype: int64
# column name: Supportive Environment Rating
# False    1225
# True       68
# Name: Supportive Environment Rating, dtype: int64
# column name: Effective School Leadership Rating
# False    1243
# True       50
# Name: Effective School Leadership Rating, dtype: int64
# column name: Strong Family-Community Ties Rating
# False    1238
# True       55
# Name: Strong Family-Community Ties Rating, dtype: int64
# column name: Trust Rating
# False    1239
# True       54
# Name: Trust Rating, dtype: int64
# column name: Student Achievement Rating
# False    1208
# True       85
# Name: Student Achievement Rating, dtype: int64
# column name: Rigorous Instruction - Percent Positive
# False    1293
# Name: Rigorous Instruction - Percent Positive, dtype: int64
# column name: Collaborative Teachers - Percent Positive
# False    1293
# Name: Collaborative Teachers - Percent Positive, dtype: int64
# column name: Supportive Environment - Percent Positive
# False    1293
# Name: Supportive Environment - Percent Positive, dtype: int64
# column name: Effective School Leadership - Percent Positive
# False    1293
# Name: Effective School Leadership - Percent Positive, dtype: int64
# column name: Strong Family-Community Ties - Percent Positive
# False    1293
# Name: Strong Family-Community Ties - Percent Positive, dtype: int64
# column name: Trust - Percent Positive
# False    1293
# Name: Trust - Percent Positive, dtype: int64
# column name: Quality Review - How interesting and challenging is the curriculum
# False    1102
# True      191
# Name: Quality Review - How interesting and challenging is the curriculum, dtype: int64
# column name: Quality Review - How effective is the teaching and learning
# False    1102
# True      191
# Name: Quality Review - How effective is the teaching and learning, dtype: int64
# column name: Quality Review - How well does the school assess what students are learning
# False    1102
# True      191
# Name: Quality Review - How well does the school assess what students are learning, dtype: int64
# column name: Quality Review - How clearly are high expectations communicated to students and staff
# False    1102
# True      191
# Name: Quality Review - How clearly are high expectations communicated to students and staff, dtype: int64
# column name: Quality Review - How well do teachers work with each other
# False    1102
# True      191
# Name: Quality Review - How well do teachers work with each other, dtype: int64
# column name: Quality Review - How safe and inclusive is the school while supporting social-emotional growth
# False    856
# True     437
# Name: Quality Review - How safe and inclusive is the school while supporting social-emotional growth, dtype: int64
# column name: Quality Review - How well does the school allocate and manage resources
# False    856
# True     437
# Name: Quality Review - How well does the school allocate and manage resources, dtype: int64
# column name: Quality Review - How well does the school identify, track, and meet its goals
# False    856
# True     437
# Name: Quality Review - How well does the school identify, track, and meet its goals, dtype: int64
# column name: Quality Review - How thoughtful is the school s approach to teacher development and evaluation
# False    856
# True     437
# Name: Quality Review - How thoughtful is the school s approach to teacher development and evaluation, dtype: int64
# column name: Quality Review - How well are school decisions evaluated and adjusted
# False    856
# True     437
# Name: Quality Review - How well are school decisions evaluated and adjusted, dtype: int64
# column name: Quality Review - Dates of Review
# False    1102
# True      191
# Name: Quality Review - Dates of Review, dtype: int64
# column name: Average Incoming ELA Proficiency (Based on 5th Grade)
# False    1293
# Name: Average Incoming ELA Proficiency (Based on 5th Grade), dtype: int64
# column name: Average Incoming Math Proficiency (Based on 5th Grade)
# False    1293
# Name: Average Incoming Math Proficiency (Based on 5th Grade), dtype: int64
# column name: Percent English Language Learners
# False    1293
# Name: Percent English Language Learners, dtype: int64
# column name: Percent Students with Disabilities
# False    1293
# Name: Percent Students with Disabilities, dtype: int64
# column name: Percent Self-Contained
# False    1293
# Name: Percent Self-Contained, dtype: int64
# column name: Economic Need Index
# False    1293
# Name: Economic Need Index, dtype: int64
# column name: Percent in Temp Housing
# False    1293
# Name: Percent in Temp Housing, dtype: int64
# column name: Percent HRA Eligible
# False    1293
# Name: Percent HRA Eligible, dtype: int64
# column name: Percent Asian
# False    1293
# Name: Percent Asian, dtype: int64
# column name: Percent Black
# False    1293
# Name: Percent Black, dtype: int64
# column name: Percent Hispanic
# False    1293
# Name: Percent Hispanic, dtype: int64
# column name: Percent White
# False    1293
# Name: Percent White, dtype: int64
# column name: Years of principal experience at this school
# False    1293
# Name: Years of principal experience at this school, dtype: int64
# column name: Percent of teachers with 3 or more years of experience
# False    1293
# Name: Percent of teachers with 3 or more years of experience, dtype: int64
# column name: Student Attendance Rate
# False    1293
# Name: Student Attendance Rate, dtype: int64
# column name: Percent of Students Chronically Absent
# False    1293
# Name: Percent of Students Chronically Absent, dtype: int64
# column name: Teacher Attendance Rate
# False    1293
# Name: Teacher Attendance Rate, dtype: int64

# %% [markdown]
# ### According to the "." values in student attendance rates, it seems to be that these are charter schools that can chooose whether or not to give information.

# %%
df['Student Attendance Rate'].isna().value_counts()
# Out:
# False    1293
# Name: Student Attendance Rate, dtype: int64

# %% [markdown]
# ### Drop values with "."

# %%
df = df[df['Student Attendance Rate'] != '.']

# %%
df = df[df['Percent of teachers with 3 or more years of experience'] != '.']

# %%
df.shape
# Out:
# (1108, 45)

# %% [markdown]
# ### Drop Rows Containing Charter Schools

# %%
df = df.drop(df.tail(143).index,inplace=False)

# %% [markdown]
# ### Convert to csv

# %%
df
# Out:
# 0       DBN                     School Name School Type Enrollment  \
# 0    01M015       P.S. 015 Roberto Clemente  Elementary        161
# 1    01M019             P.S. 019 Asher Levy  Elementary        239
# 2    01M020            P.S. 020 Anna Silver  Elementary        439
# 3    01M034  P.S. 034 Franklin D. Roosevelt         K-8        288
# 4    01M063       The STAR Academy - P.S.63  Elementary        207
# ..      ...                             ...         ...        ...
# 960  29Q038               P.S. 038 Rosedale  Elementary        283
# 961  29Q052                 P.S. 052 Queens  Elementary        380
# 962  29Q059    I.S. 059 Springfield Gardens      Middle        599
# 963  29Q095               P.S. 095 Eastwood  Elementary       1441
# 964  29Q109  Jean Nuzzi Intermediate School      Middle       1164
#
# 0   Rigorous Instruction Rating Collaborative Teachers Rating  \
# 0              Exceeding Target              Exceeding Target
# 1              Exceeding Target              Exceeding Target
# 2            Not Meeting Target            Approaching Target
# 3            Approaching Target            Approaching Target
# 4              Exceeding Target              Exceeding Target
# ..                          ...                           ...
# 960              Meeting Target            Approaching Target
# 961          Approaching Target            Approaching Target
# 962              Meeting Target                Meeting Target
# 963            Exceeding Target              Exceeding Target
# 964              Meeting Target                Meeting Target
#
# 0   Supportive Environment Rating Effective School Leadership Rating  \
# 0                Exceeding Target                   Exceeding Target
# 1                  Meeting Target                   Exceeding Target
# 2              Approaching Target                 Approaching Target
# 3              Approaching Target                 Approaching Target
# 4                  Meeting Target                     Meeting Target
# ..                            ...                                ...
# 960                Meeting Target                     Meeting Target
# 961                Meeting Target                     Meeting Target
# 962            Approaching Target                     Meeting Target
# 963                Meeting Target                   Exceeding Target
# 964                Meeting Target                     Meeting Target
#
# 0   Strong Family-Community Ties Rating        Trust Rating  ...  \
# 0                      Exceeding Target      Meeting Target  ...
# 1                      Exceeding Target      Meeting Target  ...
# 2                        Meeting Target      Meeting Target  ...
# 3                        Meeting Target  Approaching Target  ...
# 4                      Exceeding Target      Meeting Target  ...
# ..                                  ...                 ...  ...
# 960                    Exceeding Target    Exceeding Target  ...
# 961                      Meeting Target      Meeting Target  ...
# 962                    Exceeding Target      Meeting Target  ...
# 963                    Exceeding Target    Exceeding Target  ...
# 964                  Approaching Target      Meeting Target  ...
#
# 0   Percent HRA Eligible Percent Asian Percent Black Percent Hispanic  \
# 0                   0.77         0.124          0.28            0.553
# 1                  0.548         0.059         0.218            0.623
# 2                  0.647         0.289          0.13            0.506
# 3                  0.875         0.028          0.33            0.601
# 4                  0.623         0.019         0.213            0.652
# ..                   ...           ...           ...              ...
# 960                0.466         0.025         0.869            0.078
# 961                0.726          0.05         0.763            0.145
# 962                0.543          0.02         0.868            0.058
# 963                0.668         0.429         0.099            0.397
# 964                0.496         0.321         0.405            0.183
#
# 0   Percent White Years of principal experience at this school  \
# 0           0.037                                          8.9
# 1           0.067                                          9.9
# 2           0.036                                          2.9
# 3           0.028                                          2.7
# 4           0.082                                         11.9
# ..            ...                                          ...
# 960         0.021                                          4.9
# 961         0.016                                          0.9
# 962          0.01                                            1
# 963         0.014                                          7.7
# 964         0.033                                          7.7
#
# 0   Percent of teachers with 3 or more years of experience  \
# 0                                                 0.64
# 1                                                 0.75
# 2                                                0.667
# 3                                                0.545
# 4                                                0.591
# ..                                                 ...
# 960                                              0.905
# 961                                              0.882
# 962                                              0.976
# 963                                              0.921
# 964                                              0.842
#
# 0   Student Attendance Rate Percent of Students Chronically Absent  \
# 0                     0.928                                  0.227
# 1                     0.909                                  0.343
# 2                     0.925                                  0.296
# 3                     0.885                                  0.455
# 4                     0.908                                  0.347
# ..                      ...                                    ...
# 960                    0.93                                  0.234
# 961                   0.903                                  0.374
# 962                   0.903                                  0.306
# 963                   0.901                                  0.362
# 964                   0.934                                  0.205
#
# 0   Teacher Attendance Rate
# 0                     0.974
# 1                     0.966
# 2                     0.966
# 3                     0.968
# 4                     0.967
# ..                      ...
# 960                   0.967
# 961                   0.959
# 962                    0.98
# 963                   0.971
# 964                   0.966
#
# [965 rows x 45 columns]

# %%
df.shape
# Out:
# (965, 45)

# %% [markdown]
# ### Remove columns

# %%
df = df.drop(columns=['Average Incoming ELA Proficiency (Based on 5th Grade)', 
                 'Average Incoming Math Proficiency (Based on 5th Grade)',
                 'Years of principal experience at this school',
                 'Quality Review - How interesting and challenging is the curriculum',
                 'Quality Review - How effective is the teaching and learning',
                 'Quality Review - How well does the school assess what students are learning',
                 'Quality Review - How clearly are high expectations communicated to students and staff',
                 'Quality Review - How well do teachers work with each other',
                 'Quality Review - How safe and inclusive is the school while supporting social-emotional growth',
                 'Quality Review - How well does the school allocate and manage resources',
                 'Quality Review - How well does the school identify, track, and meet its goals',
                 'Quality Review - How thoughtful is the school s approach to teacher development and evaluation',
                 'Quality Review - How well are school decisions evaluated and adjusted',
                 'Quality Review - Dates of Review',
                 'Student Achievement Rating',
                 'Trust Rating',
                 'Strong Family-Community Ties Rating',
                 'Effective School Leadership Rating',
                 'Supportive Environment Rating',
                 'Collaborative Teachers Rating',
                 'Rigorous Instruction Rating'])

# %%
df.iloc[50]
# Out:
# 0
# DBN                                                                               02M217
# School Name                                               P.S./I.S. 217 Roosevelt Island
# School Type                                                                          K-8
# Enrollment                                                                           586
# Rigorous Instruction - Percent Positive                                             0.86
# Collaborative Teachers - Percent Positive                                           0.91
# Supportive Environment - Percent Positive                                           0.74
# Effective School Leadership - Percent Positive                                      0.89
# Strong Family-Community Ties - Percent Positive                                     0.96
# Trust - Percent Positive                                                             0.9
# Percent English Language Learners                                                  0.148
# Percent Students with Disabilities                                                  0.15
# Percent Self-Contained                                                              0.01
# Economic Need Index                                                                0.295
# Percent in Temp Housing                                                            0.032
# Percent HRA Eligible                                                               0.198
# Percent Asian                                                                      0.287
# Percent Black                                                                       0.14
# Percent Hispanic                                                                    0.15
# Percent White                                                                      0.358
# Percent of teachers with 3 or more years of experience                             0.714
# Student Attendance Rate                                                            0.949
# Percent of Students Chronically Absent                                             0.151
# Teacher Attendance Rate                                                            0.966
# Name: 50, dtype: object

# %%
df = df.rename(columns={'DBN': 'dbn', 
                                        'School Name': 'school_name', 
                                        'School Type': 'school_type', 
                                        'Enrollment': 'enrollment', 
                                        'Rigorous Instruction - Percent Positive': 'rigorous_instruction', 
                                        'Collaborative Teachers - Percent Positive': 'collab_teachers',
                                        'Supportive Environment - Percent Positive': 'support_environ',
                                        'Effective School Leadership - Percent Positive': 'effective_school_leadership',
                                        'Strong Family-Community Ties - Percent Positive': 'strong_fam_community_ties',
                                        'Trust - Percent Positive':'trust',
                                        'Percent English Language Learners':'english_language_learners',
                                        'Percent Students with Disabilities':'students_disabilities',
                                        'Percent Self-Contained':'self_contained',
                                        'Economic Need Index':'economic_need_index',
                                        'Percent in Temp Housing':'temp_housing',
                                        'Percent HRA Eligible':'hra_eligible',
                                        'Percent Asian':'asian',
                                        'Percent Black':'black',
                                        'Percent Hispanic':'hispanic',
                                        'Percent White':'white',
                                        'Percent of teachers with 3 or more years of experience':'teachers_3_or_more_yrs_exp',
                                        'Student Attendance Rate':'student_attendance_rate',
                                        'Percent of Students Chronically Absent':'chronically_absent',
                                        'Teacher Attendance Rate':'teacher_attendance_rate'})

# %%
df
# Out:
# 0       dbn                     school_name school_type enrollment  \
# 0    01M015       P.S. 015 Roberto Clemente  Elementary        161
# 1    01M019             P.S. 019 Asher Levy  Elementary        239
# 2    01M020            P.S. 020 Anna Silver  Elementary        439
# 3    01M034  P.S. 034 Franklin D. Roosevelt         K-8        288
# 4    01M063       The STAR Academy - P.S.63  Elementary        207
# ..      ...                             ...         ...        ...
# 960  29Q038               P.S. 038 Rosedale  Elementary        283
# 961  29Q052                 P.S. 052 Queens  Elementary        380
# 962  29Q059    I.S. 059 Springfield Gardens      Middle        599
# 963  29Q095               P.S. 095 Eastwood  Elementary       1441
# 964  29Q109  Jean Nuzzi Intermediate School      Middle       1164
#
# 0   rigorous_instruction collab_teachers support_environ  \
# 0                   0.85             0.9            0.83
# 1                   0.87            0.92            0.85
# 2                    0.7            0.77            0.74
# 3                   0.74            0.66            0.64
# 4                    0.8            0.86            0.87
# ..                   ...             ...             ...
# 960                  0.9            0.91            0.86
# 961                 0.73            0.87            0.78
# 962                 0.81            0.86            0.65
# 963                 0.86            0.93            0.88
# 964                 0.81            0.81            0.67
#
# 0   effective_school_leadership strong_fam_community_ties trust  ...  \
# 0                          0.96                      0.97  0.94  ...
# 1                           0.9                      0.98  0.91  ...
# 2                           0.8                      0.95  0.86  ...
# 3                          0.66                      0.94  0.76  ...
# 4                           0.9                      0.96  0.92  ...
# ..                          ...                       ...   ...  ...
# 960                        0.95                      0.98  0.96  ...
# 961                        0.88                      0.95  0.93  ...
# 962                        0.91                      0.94  0.86  ...
# 963                        0.95                      0.99  0.96  ...
# 964                        0.77                      0.86  0.84  ...
#
# 0   temp_housing hra_eligible  asian  black hispanic  white  \
# 0          0.398         0.77  0.124   0.28    0.553  0.037
# 1          0.155        0.548  0.059  0.218    0.623  0.067
# 2          0.164        0.647  0.289   0.13    0.506  0.036
# 3          0.295        0.875  0.028   0.33    0.601  0.028
# 4          0.261        0.623  0.019  0.213    0.652  0.082
# ..           ...          ...    ...    ...      ...    ...
# 960        0.067        0.466  0.025  0.869    0.078  0.021
# 961        0.311        0.726   0.05  0.763    0.145  0.016
# 962        0.095        0.543   0.02  0.868    0.058   0.01
# 963         0.13        0.668  0.429  0.099    0.397  0.014
# 964        0.063        0.496  0.321  0.405    0.183  0.033
#
# 0   teachers_3_or_more_yrs_exp student_attendance_rate chronically_absent  \
# 0                         0.64                   0.928              0.227
# 1                         0.75                   0.909              0.343
# 2                        0.667                   0.925              0.296
# 3                        0.545                   0.885              0.455
# 4                        0.591                   0.908              0.347
# ..                         ...                     ...                ...
# 960                      0.905                    0.93              0.234
# 961                      0.882                   0.903              0.374
# 962                      0.976                   0.903              0.306
# 963                      0.921                   0.901              0.362
# 964                      0.842                   0.934              0.205
#
# 0   teacher_attendance_rate
# 0                     0.974
# 1                     0.966
# 2                     0.966
# 3                     0.968
# 4                     0.967
# ..                      ...
# 960                   0.967
# 961                   0.959
# 962                    0.98
# 963                   0.971
# 964                   0.966
#
# [965 rows x 24 columns]

# %%
list(df.columns)
# Out:
# ['dbn',
#  'school_name',
#  'school_type',
#  'enrollment',
#  'rigorous_instruction',
#  'collab_teachers',
#  'support_environ',
#  'effective_school_leadership',
#  'strong_fam_community_ties',
#  'trust',
#  'english_language_learners',
#  'students_disabilities',
#  'self_contained',
#  'economic_need_index',
#  'temp_housing',
#  'hra_eligible',
#  'asian',
#  'black',
#  'hispanic',
#  'white',
#  'teachers_3_or_more_yrs_exp',
#  'student_attendance_rate',
#  'chronically_absent',
#  'teacher_attendance_rate']

# %%
df.to_csv('sqr.csv', index=False)
